# %%
import pandas as pd
import numpy as np

from preprocessing_node import *

# %%
#df = pd.read_csv('../data/02_intermediate/prediction_data_backup.csv')
df = pd.read_csv('../data/02_intermediate/prediction_data.csv')

df.loc[:, 'predicted_total_cases'].plot(color='red')
df.loc[:, 'total_cases'].plot(color='blue', linestyle='dotted')

df.head()
# Out:
#    year  weekofyear  ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0  2008          18  -0.0189 -0.018900  0.102729  0.091200
# 1  2008          19  -0.0180 -0.012400  0.082043  0.072314
# 2  2008          20  -0.0015 -0.012400  0.151083  0.091529
# 3  2008          21  -0.0015 -0.019867  0.124329  0.125686
# 4  2008          22   0.0568  0.039833  0.062267  0.075914
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 78.60             298.492857             298.550000
# 1                 12.56             298.475714             298.557143
# 2                  3.66             299.455714             299.357143
# 3                  0.00             299.690000             299.728571
# 4                  0.76             299.780000             299.671429
#
#    reanalysis_dew_point_temp_k  ...  station_avg_temp_c  \
# 0                   294.527143  ...           26.528571
# 1                   294.395714  ...           26.071429
# ...
